# %%
from tqdm import tqdm_notebook
import tensorflow as tf

# %%
quiz1(x1)  quiz2(x2)  midterm1(x3)  final(Y)    
   73         80          75           152
   93         88          93           185
   89         91          90           180
   96         98         100           198
   73         66          70           142

# %% [markdown]
# #### multi-variable linear regression

# %%
import tensorflow as tf

tf.set_random_seed(777) # 재현을 위해

x1_data = [73., 93., 89., 96., 73.]
x2_data = [80., 88., 91., 98., 66.]
x3_data = [75., 93., 90., 100., 70.]

y_data = [152., 185., 180., 196., 142.]


x1 = tf.placeholder(tf.float32)
x2 = tf.placeholder(tf.float32)
x3 = tf.placeholder(tf.float32)

Y = tf.placeholder(tf.float32)

w1 = tf.Variable(tf.random_normal([1]), name = 'weight1')
w2 = tf.Variable(tf.random_normal([1]), name = 'weight2')
w3 = tf.Variable(tf.random_normal([1]), name = 'weight3')
b  = tf.Variable(tf.random_normal([1]), name = 'bias')

hypothesis = x1 * w1 + x2 * w3 + x3 * w3 + b
print(hypothesis)

cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 1e-5)
train = optimizer.minimize(cost)
# Out:
# Tensor("add_2:0", dtype=float32)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in tqdm_notebook(range(2001)):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                    feed_dict = {x1 : x1_data, x2 : x2_data, x3 : x3_data, Y : y_data})
    
    if step % 100 == 0 or step < 10:
        print("\nStep : {} \nCost : {} \nPrediction : \n{}".format(step, cost_val, hy_val))
# Out:
# HBox(children=(IntProgress(value=0, max=2001), HTML(value='')))
# Step : 0
# Cost : 25309.24609375
# Prediction :
# [ 9.406108 15.630229 13.277722 13.773341 13.453403]
#
# Step : 1
# Cost : 1783.132080078125
# Prediction :
# [113.85797  139.70802  136.26949  147.94751  107.531425]
#
# Step : 2
# Cost : 125.85054016113281
# Prediction :
# [141.58087 172.63995 168.91315 183.55911 132.50107]
#
# Step : 3
# Cost : 9.104373931884766
# Prediction :
# [148.93886 181.38057 177.57721 193.01088 139.12837]
#
# Step : 4
# Cost : 0.8801765441894531
# Prediction :
# [150.89174 183.70049 179.87675 195.5195  140.88742]
#
# Step : 5
# Cost : 0.30080538988113403
# Prediction :
# [151.41003 184.31625 180.48709 196.18532 141.35435]
#
# Step : 6
# Cost : 0.2599765360355377
# Prediction :
# [151.54753 184.4797  180.64905 196.36198 141.47832]
#
# Step : 7
# Cost : 0.2570776045322418
# Prediction :
# [151.58401 184.52315 180.69205 196.40889 141.51129]
#
# Step : 8
# Cost : 0.2568546235561371
# Prediction :
# [151.59364 184.53467 180.70343 196.42128 141.52008]
#
# Step : 9
# Cost : 0.2568219304084778
# Prediction :
# [151.59616 184.53777 180.70647 196.42455 141.52248]
#
# Step : 100
# Cost : 0.2549284100532532
# Prediction :
# [151.59232 184.54239 180.70638 196.42287 141.52963]
#
# Step : 200
# Cost : 0.2529192864894867
# Prediction :
# [151.58717 184.54619 180.7051  196.41975 141.53645]
#
# Step : 300
# Cost : 0.2509911358356476
# Prediction :
# [151.58214 184.54991 180.70386 196.41669 141.54314]
#
# Step : 400
# Cost : 0.24913795292377472
# Prediction :
# [151.5772  184.55354 180.70264 196.4137  141.54971]
#
# Step : 500
# Cost : 0.24735967814922333
# Prediction :
# [151.57233 184.55713 180.70145 196.41074 141.55612]
#
# Step : 600
# Cost : 0.24564942717552185
# Prediction :
# [151.56758 184.56062 180.70027 196.40787 141.56242]
#
# Step : 700
# Cost : 0.24400019645690918
# Prediction :
# [151.56293 184.56406 180.69911 196.40504 141.5686 ]
#
# Step : 800
# Cost : 0.24241705238819122
# Prediction :
# [151.55835 184.56743 180.69798 196.40227 141.57466]
#
# Step : 900
# Cost : 0.24090059101581573
# Prediction :
# [151.55386 184.57072 180.69688 196.39955 141.5806 ]
#
# Step : 1000
# Cost : 0.23943260312080383
# Prediction :
# [151.54948 184.57396 180.69579 196.3969  141.58643]
#
# Step : 1100
# Cost : 0.2380257397890091
# Prediction :
# [151.54517 184.57713 180.69472 196.39427 141.59213]
#
# Step : 1200
# Cost : 0.2366788685321808
# Prediction :
# [151.54095 184.58026 180.6937  196.39175 141.59775]
#
# Step : 1300
# Cost : 0.23537671566009521
# Prediction :
# [151.53682 184.5833  180.69267 196.3892  141.60323]
#
# Step : 1400
# Cost : 0.2341247797012329
# Prediction :
# [151.53275 184.58629 180.69165 196.38675 141.60861]
#
# Step : 1500
# Cost : 0.23292896151542664
# Prediction :
# [151.52876 184.5892  180.69067 196.38434 141.61389]
#
# Step : 1600
# Cost : 0.23176565766334534
# Prediction :
# [151.52486 184.5921  180.6897  196.38196 141.61906]
#
# Step : 1700
# Cost : 0.23066052794456482
# Prediction :
# [151.52104 184.5949  180.68877 196.37962 141.62413]
#
# Step : 1800
# Cost : 0.22959311306476593
# Prediction :
# [151.51729 184.59766 180.68784 196.37737 141.62912]
#
# Step : 1900
# Cost : 0.22856339812278748
# Prediction :
# [151.51361 184.60039 180.68692 196.37514 141.63399]
#
# Step : 2000
# Cost : 0.2275819033384323
# Prediction :
# [151.51001 184.60303 180.68604 196.37296 141.63876]

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in tqdm_notebook(range(2001)):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                   feed_dict={x1: x1_data, x2: x2_data, x3: x3_data, Y: y_data})

    if step % 100 == 0 or step < 10 :
        print("\nStep : {} \nCost : {} \nPrediction :\n{}".format(step, cost_val, hy_val))
# Out:
# HBox(children=(IntProgress(value=0, max=2001), HTML(value='')))
# Step : 0
# Cost : 25309.24609375
# Prediction :
# [ 9.406108 15.630229 13.277722 13.773341 13.453403]
#
# Step : 1
# Cost : 1783.132080078125
# Prediction :
# [113.85797  139.70802  136.26949  147.94751  107.531425]
#
# Step : 2
# Cost : 125.85054016113281
# Prediction :
# [141.58087 172.63995 168.91315 183.55911 132.50107]
#
# Step : 3
# Cost : 9.104373931884766
# Prediction :
# [148.93886 181.38057 177.57721 193.01088 139.12837]
#
# Step : 4
# Cost : 0.8801765441894531
# Prediction :
# [150.89174 183.70049 179.87675 195.5195  140.88742]
#
# Step : 5
# Cost : 0.30080538988113403
# Prediction :
# [151.41003 184.31625 180.48709 196.18532 141.35435]
#
# Step : 6
# Cost : 0.2599765360355377
# Prediction :
# [151.54753 184.4797  180.64905 196.36198 141.47832]
#
# Step : 7
# Cost : 0.2570776045322418
# Prediction :
# [151.58401 184.52315 180.69205 196.40889 141.51129]
#
# Step : 8
# Cost : 0.2568546235561371
# Prediction :
# [151.59364 184.53467 180.70343 196.42128 141.52008]
#
# Step : 9
# Cost : 0.2568219304084778
# Prediction :
# [151.59616 184.53777 180.70647 196.42455 141.52248]
#
# Step : 100
# Cost : 0.2549284100532532
# Prediction :
# [151.59232 184.54239 180.70638 196.42287 141.52963]
#
# Step : 200
# Cost : 0.2529192864894867
# Prediction :
# [151.58717 184.54619 180.7051  196.41975 141.53645]
#
# Step : 300
# Cost : 0.2509911358356476
# Prediction :
# [151.58214 184.54991 180.70386 196.41669 141.54314]
#
# Step : 400
# Cost : 0.24913795292377472
# Prediction :
# [151.5772  184.55354 180.70264 196.4137  141.54971]
#
# Step : 500
# Cost : 0.24735967814922333
# Prediction :
# [151.57233 184.55713 180.70145 196.41074 141.55612]
#
# Step : 600
# Cost : 0.24564942717552185
# Prediction :
# [151.56758 184.56062 180.70027 196.40787 141.56242]
#
# Step : 700
# Cost : 0.24400019645690918
# Prediction :
# [151.56293 184.56406 180.69911 196.40504 141.5686 ]
#
# Step : 800
# Cost : 0.24241705238819122
# Prediction :
# [151.55835 184.56743 180.69798 196.40227 141.57466]
#
# Step : 900
# Cost : 0.24090059101581573
# Prediction :
# [151.55386 184.57072 180.69688 196.39955 141.5806 ]
#
# Step : 1000
# Cost : 0.23943260312080383
# Prediction :
# [151.54948 184.57396 180.69579 196.3969  141.58643]
#
# Step : 1100
# Cost : 0.2380257397890091
# Prediction :
# [151.54517 184.57713 180.69472 196.39427 141.59213]
#
# Step : 1200
# Cost : 0.2366788685321808
# Prediction :
# [151.54095 184.58026 180.6937  196.39175 141.59775]
#
# Step : 1300
# Cost : 0.23537671566009521
# Prediction :
# [151.53682 184.5833  180.69267 196.3892  141.60323]
#
# Step : 1400
# Cost : 0.2341247797012329
# Prediction :
# [151.53275 184.58629 180.69165 196.38675 141.60861]
#
# Step : 1500
# Cost : 0.23292896151542664
# Prediction :
# [151.52876 184.5892  180.69067 196.38434 141.61389]
#
# Step : 1600
# Cost : 0.23176565766334534
# Prediction :
# [151.52486 184.5921  180.6897  196.38196 141.61906]
#
# Step : 1700
# Cost : 0.23066052794456482
# Prediction :
# [151.52104 184.5949  180.68877 196.37962 141.62413]
#
# Step : 1800
# Cost : 0.22959311306476593
# Prediction :
# [151.51729 184.59766 180.68784 196.37737 141.62912]
#
# Step : 1900
# Cost : 0.22856339812278748
# Prediction :
# [151.51361 184.60039 180.68692 196.37514 141.63399]
#
# Step : 2000
# Cost : 0.2275819033384323
# Prediction :
# [151.51001 184.60303 180.68604 196.37296 141.63876]

# %% [markdown]
# #### multi-variable matmul linear regression

# %%
import tensorflow as tf
tf.set_random_seed(777) 

x_data = [[73., 80., 75.], 
          [93., 88., 93.],
          [89., 91., 90.], 
          [96., 98., 100.], 
          [73., 66., 70.]]
y_data = [[152.], [185.], [180.], [196.], [142.]]

X = tf.placeholder(tf.float32, shape = [None, 3])
Y = tf.placeholder(tf.float32, shape = [None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]),    name = 'bias')

hypothesis = tf.matmul(X, W) + b
cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 1e-5)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in tqdm_notebook(range(2001)):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                    feed_dict = {X : x_data, Y : y_data})
    
    if step % 100 == 0 or step < 10:
        print("\nStep : {} \nCost : {} \nPrediction : \n{}".format(step, cost_val, hy_val))
# Out:
# HBox(children=(IntProgress(value=0, max=2001), HTML(value='')))
# Step : 0
# Cost : 56385.375
# Prediction :
# [[-58.458176]
#  [-68.91279 ]
#  [-68.36896 ]
#  [-77.1176  ]
#  [-50.047306]]
#
# Step : 1
# Cost : 17674.509765625
# Prediction :
# [[34.27563 ]
#  [42.5463  ]
#  [41.4536  ]
#  [42.476444]
#  [34.96787 ]]
#
# Step : 2
# Cost : 5540.7080078125
# Prediction :
# [[ 86.193886]
#  [104.94814 ]
#  [102.939224]
#  [109.43279 ]
#  [ 82.56472 ]]
#
# Step : 3
# Cost : 1737.4066162109375
# Prediction :
# [[115.261024]
#  [139.88464 ]
#  [137.36275 ]
#  [146.9192  ]
#  [109.21242 ]]
#
# Step : 4
# Cost : 545.2735595703125
# Prediction :
# [[131.53464 ]
#  [159.4443  ]
#  [156.63521 ]
#  [167.90648 ]
#  [124.131485]]
#
# Step : 5
# Cost : 171.60275268554688
# Prediction :
# [[140.64566]
#  [170.39505]
#  [167.42519]
#  [179.65651]
#  [132.48409]]
#
# Step : 6
# Cost : 54.4771728515625
# Prediction :
# [[145.74657]
#  [176.52594]
#  [173.46606]
#  [186.23494]
#  [137.16037]]
#
# Step : 7
# Cost : 17.764415740966797
# Prediction :
# [[148.60239]
#  [179.9584 ]
#  [176.84814]
#  [189.91797]
#  [139.77844]]
#
# Step : 8
# Cost : 6.256844997406006
# Prediction :
# [[150.20126]
#  [181.88013]
#  [178.74164]
#  [191.98   ]
#  [141.24419]]
#
# Step : 9
# Cost : 2.6498703956604004
# Prediction :
# [[151.0964 ]
#  [182.956  ]
#  [179.80174]
#  [193.13445]
#  [142.06477]]
#
# Step : 100
# Cost : 0.9991838335990906
# Prediction :
# [[152.23586]
#  [184.32362]
#  [181.14995]
#  [194.60666]
#  [143.1041 ]]
#
# Step : 200
# Cost : 0.9949213266372681
# Prediction :
# [[152.23663]
#  [184.32265]
#  [181.1496 ]
#  [194.61073]
#  [143.09917]]
#
# Step : 300
# Cost : 0.9907093048095703
# Prediction :
# [[152.23737]
#  [184.32173]
#  [181.14929]
#  [194.6148 ]
#  [143.09431]]
#
# Step : 400
# Cost : 0.9865163564682007
# Prediction :
# [[152.238  ]
#  [184.32083]
#  [181.14893]
#  [194.61885]
#  [143.08952]]
#
# Step : 500
# Cost : 0.9823614358901978
# Prediction :
# [[152.2386 ]
#  [184.31999]
#  [181.14853]
#  [194.62286]
#  [143.08482]]
#
# Step : 600
# Cost : 0.9782418012619019
# Prediction :
# [[152.23914]
#  [184.31921]
#  [181.14816]
#  [194.62686]
#  [143.08017]]
#
# Step : 700
# Cost : 0.9741533398628235
# Prediction :
# [[152.23956]
#  [184.31845]
#  [181.14774]
#  [194.63081]
#  [143.07559]]
#
# Step : 800
# Cost : 0.9700959920883179
# Prediction :
# [[152.23997]
#  [184.31775]
#  [181.14731]
#  [194.63475]
#  [143.07108]]
#
# Step : 900
# Cost : 0.9660454988479614
# Prediction :
# [[152.24034]
#  [184.3171 ]
#  [181.14687]
#  [194.63872]
#  [143.06664]]
#
# Step : 1000
# Cost : 0.9620314836502075
# Prediction :
# [[152.24062]
#  [184.31647]
#  [181.14641]
#  [194.64262]
#  [143.06223]]
#
# Step : 1100
# Cost : 0.9580670595169067
# Prediction :
# [[152.24084]
#  [184.31587]
#  [181.14594]
#  [194.6465 ]
#  [143.0579 ]]
#
# Step : 1200
# Cost : 0.9541133642196655
# Prediction :
# [[152.24103]
#  [184.31532]
#  [181.14545]
#  [194.65036]
#  [143.05362]]
#
# Step : 1300
# Cost : 0.9501869082450867
# Prediction :
# [[152.24117]
#  [184.3148 ]
#  [181.14493]
#  [194.6542 ]
#  [143.04941]]
#
# Step : 1400
# Cost : 0.9462810754776001
# Prediction :
# [[152.24123]
#  [184.31433]
#  [181.14441]
#  [194.65804]
#  [143.04524]]
#
# Step : 1500
# Cost : 0.9424190521240234
# Prediction :
# [[152.24127]
#  [184.31387]
#  [181.14388]
#  [194.66182]
#  [143.04112]]
#
# Step : 1600
# Cost : 0.9385656118392944
# Prediction :
# [[152.24126]
#  [184.31348]
#  [181.14333]
#  [194.6656 ]
#  [143.03706]]
#
# Step : 1700
# Cost : 0.9347543716430664
# Prediction :
# [[152.2412 ]
#  [184.3131 ]
#  [181.14279]
#  [194.66939]
#  [143.03308]]
#
# Step : 1800
# Cost : 0.9309464693069458
# Prediction :
# [[152.24109]
#  [184.31274]
#  [181.14218]
#  [194.67311]
#  [143.02911]]
#
# Step : 1900
# Cost : 0.9271866083145142
# Prediction :
# [[152.24094]
#  [184.31244]
#  [181.14163]
#  [194.67683]
#  [143.0252 ]]
#
# Step : 2000
# Cost : 0.9234170913696289
# Prediction :
# [[152.24075]
#  [184.31216]
#  [181.141  ]
#  [194.68056]
#  [143.02136]]

# %% [markdown]
# #### file input linear regression

# %%
import numpy as np

xy = np.loadtxt('./data/data-01-test-score.csv', delimiter=',', dtype=np.float32)
xy
# Out:
# array([[ 73.,  80.,  75., 152.],
#        [ 93.,  88.,  93., 185.],
#        [ 89.,  91.,  90., 180.],
#        [ 96.,  98., 100., 196.],
#        [ 73.,  66.,  70., 142.],
#        [ 53.,  46.,  55., 101.],
#        [ 69.,  74.,  77., 149.],
#        [ 47.,  56.,  60., 115.],
#        [ 87.,  79.,  90., 175.],
#        [ 79.,  70.,  88., 164.],
#        [ 69.,  70.,  73., 141.],
#        [ 70.,  65.,  74., 141.],
#        [ 93.,  95.,  91., 184.],
#        [ 79.,  80.,  73., 152.],
#        [ 70.,  73.,  78., 148.],
#        [ 93.,  89.,  96., 192.],
#        [ 78.,  75.,  68., 147.],
#        [ 81.,  90.,  93., 183.],
#        [ 88.,  92.,  86., 177.],
#        [ 78.,  83.,  77., 159.],
#        [ 82.,  86.,  90., 177.],
#        [ 86.,  82.,  89., 175.],
#        [ 78.,  83.,  85., 175.],
#        [ 76.,  83.,  71., 149.],
#        [ 96.,  93.,  95., 192.]], dtype=float32)

# %%
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

print("# Check the train data")
print("-"*50)
print("x_data.shape : {},   len(x_data) : {} \nx_data : \n{}".format(x_data.shape, len(x_data), x_data))
print("-"*50)
print("y_data.shape : {},   len(y_data) : {} \ny_data : \n{}".format(y_data.shape, len(y_data), y_data))
# Out:
# # Check the train data
# --------------------------------------------------
# x_data.shape : (25, 3),   len(x_data) : 25
# x_data :
# [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]
#  [ 69.  74.  77.]
#  [ 47.  56.  60.]
#  [ 87.  79.  90.]
#  [ 79.  70.  88.]
#  [ 69.  70.  73.]
#  [ 70.  65.  74.]
#  [ 93.  95.  91.]
#  [ 79.  80.  73.]
#  [ 70.  73.  78.]
#  [ 93.  89.  96.]
#  [ 78.  75.  68.]
#  [ 81.  90.  93.]
#  [ 88.  92.  86.]
#  [ 78.  83.  77.]
#  [ 82.  86.  90.]
#  [ 86.  82.  89.]
#  [ 78.  83.  85.]
#  [ 76.  83.  71.]
#  [ 96.  93.  95.]]
# --------------------------------------------------
# y_data.shape : (25, 1),   len(y_data) : 25
# y_data :
# [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]
#  [149.]
#  [115.]
#  [175.]
#  [164.]
#  [141.]
#  [141.]
#  [184.]
#  [152.]
#  [148.]
#  [192.]
#  [147.]
#  [183.]
#  [177.]
#  [159.]
#  [177.]
#  [175.]
#  [175.]
#  [149.]
#  [192.]]

# %%
import tensorflow as tf
tf.set_random_seed(777)

X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = tf.matmul(X, W) + b
cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in tqdm_notebook(range(2001)):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                    feed_dict = {X : x_data, Y : y_data})
    
    if step % 100 == 0 or step < 10:
        print("\nStep : {} \nCost : {} \nPrediction : \n{}".format(step, cost_val, hy_val))
# Out:
# HBox(children=(IntProgress(value=0, max=2001), HTML(value='')))
# Step : 0
# Cost : 37653.984375
# Prediction :
# [[-25.132015]
#  [-35.24543 ]
#  [-31.989025]
#  [-36.701427]
#  [-26.571817]
#  [-23.006609]
#  [-28.792574]
#  [-23.052807]
#  [-36.35996 ]
#  [-38.214752]
#  [-27.328386]
#  [-29.869019]
#  [-31.243298]
#  [-23.6406  ]
#  [-29.879856]
#  [-37.070248]
#  [-21.815804]
#  [-34.584045]
#  [-28.713585]
#  [-25.473568]
#  [-33.8438  ]
#  [-34.546   ]
#  [-31.308651]
#  [-21.10814 ]
#  [-34.87119 ]]
#
# Step : 1
# Cost : 13947.6103515625
# Prediction :
# [[46.33806 ]
#  [50.65833 ]
#  [52.651524]
#  [55.4798  ]
#  [38.943596]
#  [25.29753 ]
#  [40.209206]
#  [28.102087]
#  [43.925495]
#  [36.15214 ]
#  [39.150978]
#  [35.682976]
#  [56.200893]
#  [49.049583]
#  [39.439728]
#  [50.10273 ]
#  [47.411575]
#  [48.224842]
#  [54.651234]
#  [49.117943]
#  [47.071774]
#  [46.044235]
#  [45.83734 ]
#  [50.947933]
#  [54.157017]]
#
# Step : 2
# Cost : 5182.68701171875
# Prediction :
# [[ 89.79476 ]
#  [102.89255 ]
#  [104.116974]
#  [111.53083 ]
#  [ 78.780464]
#  [ 54.669968]
#  [ 82.16633 ]
#  [ 59.20781 ]
#  [ 92.7444  ]
#  [ 81.37341 ]
#  [ 79.57418 ]
#  [ 75.54303 ]
#  [109.37058 ]
#  [ 93.24757 ]
#  [ 81.59033 ]
#  [103.10909 ]
#  [ 89.50382 ]
#  [ 98.57753 ]
#  [105.34021 ]
#  [ 94.472374]
#  [ 96.27318 ]
#  [ 95.04797 ]
#  [ 92.74637 ]
#  [ 94.75977 ]
#  [108.29065 ]]
#
# Step : 3
# Cost : 1942.03369140625
# Prediction :
# [[116.21787 ]
#  [134.65393 ]
#  [135.4102  ]
#  [145.61281 ]
#  [103.00345 ]
#  [ 72.53094 ]
#  [107.678894]
#  [ 78.12257 ]
#  [122.43    ]
#  [108.87262 ]
#  [104.153854]
#  [ 99.78104 ]
#  [141.69955 ]
#  [120.12079 ]
#  [107.2208  ]
#  [135.34033 ]
#  [115.09647 ]
#  [129.19516 ]
#  [136.16055 ]
#  [122.04912 ]
#  [126.19071 ]
#  [124.84547 ]
#  [121.26973 ]
#  [121.39764 ]
#  [141.20653 ]]
#
# Step : 4
# Cost : 743.8551635742188
# Prediction :
# [[132.28368 ]
#  [153.96675 ]
#  [154.43768 ]
#  [166.33649 ]
#  [117.73235 ]
#  [ 83.392334]
#  [123.19231 ]
#  [ 89.6246  ]
#  [140.48155 ]
#  [125.595894]
#  [119.09985 ]
#  [114.52002 ]
#  [161.3563  ]
#  [136.45967 ]
#  [122.806145]
#  [154.93925 ]
#  [130.65654 ]
#  [147.81282 ]
#  [154.89977 ]
#  [138.81613 ]
#  [144.38266 ]
#  [142.96454 ]
#  [138.61368 ]
#  [137.59283 ]
#  [161.22092 ]]
#
# Step : 5
# Cost : 300.8373107910156
# Prediction :
# [[142.05165 ]
#  [165.71019 ]
#  [166.0069  ]
#  [178.93755 ]
#  [126.688354]
#  [ 89.99763 ]
#  [132.62567 ]
#  [ 96.61929 ]
#  [151.45895 ]
#  [135.7668  ]
#  [128.18805 ]
#  [123.4831  ]
#  [173.30762 ]
#  [146.39308 ]
#  [132.2835  ]
#  [166.85703 ]
#  [140.11623 ]
#  [159.1339  ]
#  [166.29295 ]
#  [149.0102  ]
#  [155.44478 ]
#  [153.98251 ]
#  [149.1599  ]
#  [147.43831 ]
#  [173.39052 ]]
#
# Step : 6
# Cost : 137.0222625732422
# Prediction :
# [[147.99026]
#  [172.85106]
#  [173.04115]
#  [186.59969]
#  [132.13416]
#  [ 94.01497]
#  [138.3621 ]
#  [100.87329]
#  [158.13493]
#  [141.95355]
#  [133.7144 ]
#  [128.93411]
#  [180.5737 ]
#  [152.43166]
#  [138.0469 ]
#  [174.10426]
#  [145.86661]
#  [166.01823]
#  [173.2194 ]
#  [155.20763]
#  [162.17165]
#  [160.68268]
#  [155.57278]
#  [153.42285]
#  [180.79007]]
#
# Step : 7
# Cost : 76.43635559082031
# Prediction :
# [[151.60042]
#  [177.19331]
#  [177.3179 ]
#  [191.2587 ]
#  [135.44556]
#  [ 96.45872]
#  [141.85057]
#  [103.4608 ]
#  [162.19543]
#  [145.71774]
#  [137.075  ]
#  [132.24962]
#  [184.99089]
#  [156.10197]
#  [141.55206]
#  [178.51158]
#  [149.3615 ]
#  [170.20485]
#  [177.42987]
#  [158.97487]
#  [166.26244]
#  [164.75737]
#  [159.47238]
#  [157.05975]
#  [185.28922]]
#
# Step : 8
# Cost : 54.017330169677734
# Prediction :
# [[153.79472 ]
#  [179.83386 ]
#  [179.91794 ]
#  [194.09163 ]
#  [137.45912 ]
#  [ 97.94562 ]
#  [143.97218 ]
#  [105.034996]
#  [164.66556 ]
#  [148.00887 ]
#  [139.11865 ]
#  [134.26663 ]
#  [187.6758  ]
#  [158.33226 ]
#  [143.68404 ]
#  [181.1921  ]
#  [151.48495 ]
#  [172.75105 ]
#  [179.98883 ]
#  [161.26445 ]
#  [168.75035 ]
#  [167.23564 ]
#  [161.84378 ]
#  [159.26917 ]
#  [188.02472 ]]
#
# Step : 9
# Cost : 45.70964050292969
# Prediction :
# [[155.12814]
#  [181.43971]
#  [181.49844]
#  [195.81424]
#  [138.68353]
#  [ 98.85074]
#  [145.26266]
#  [105.99306]
#  [166.16864]
#  [149.40428]
#  [140.36157]
#  [135.49408]
#  [189.3074 ]
#  [159.68695]
#  [144.98106]
#  [182.82259]
#  [152.7745 ]
#  [174.29985]
#  [181.54364]
#  [162.6555 ]
#  [170.26361]
#  [168.7432 ]
#  [163.28592]
#  [160.61055]
#  [189.68787]]
#
# Step : 100
# Cost : 38.247440338134766
# Prediction :
# [[157.00876]
#  [183.98354]
#  [183.84923]
#  [198.4913 ]
#  [140.59766]
#  [100.47543]
#  [147.36084]
#  [107.67196]
#  [168.75465]
#  [152.08328]
#  [142.34752]
#  [137.6222 ]
#  [191.62134]
#  [161.46236]
#  [147.14417]
#  [185.48923]
#  [154.41138]
#  [176.826  ]
#  [183.6874 ]
#  [164.56418]
#  [172.72316]
#  [171.22565]
#  [165.57355]
#  [162.23851]
#  [192.22466]]
#
# Step : 200
# Cost : 35.61164855957031
# Prediction :
# [[156.80782 ]
#  [184.03923 ]
#  [183.74083 ]
#  [198.4966  ]
#  [140.61221 ]
#  [100.711205]
#  [147.46483 ]
#  [107.88012 ]
#  [169.02634 ]
#  [152.63414 ]
#  [142.40964 ]
#  [137.86186 ]
#  [191.38823 ]
#  [161.11212 ]
#  [147.30667 ]
#  [185.63583 ]
#  [154.02025 ]
#  [176.95985 ]
#  [183.39978 ]
#  [164.29707 ]
#  [172.84389 ]
#  [171.37927 ]
#  [165.62828 ]
#  [161.75296 ]
#  [192.17758 ]]
#
# Step : 300
# Cost : 33.19538497924805
# Prediction :
# [[156.61624]
#  [184.09175]
#  [183.63715]
#  [198.50188]
#  [140.62503]
#  [100.93607]
#  [147.56522]
#  [108.08097]
#  [169.28543]
#  [153.16068]
#  [142.46924]
#  [138.09077]
#  [191.16501]
#  [160.7765 ]
#  [147.46283]
#  [185.77568]
#  [153.64484]
#  [177.08943]
#  [183.12463]
#  [164.04175]
#  [172.96013]
#  [171.52585]
#  [165.68144]
#  [161.28856]
#  [192.1319 ]]
#
# Step : 400
# Cost : 30.980134963989258
# Prediction :
# [[156.43356 ]
#  [184.14128 ]
#  [183.538   ]
#  [198.50714 ]
#  [140.63622 ]
#  [101.15053 ]
#  [147.66211 ]
#  [108.274796]
#  [169.53253 ]
#  [153.66399 ]
#  [142.52647 ]
#  [138.30937 ]
#  [190.95128 ]
#  [160.45488 ]
#  [147.61292 ]
#  [185.90904 ]
#  [153.28448 ]
#  [177.21492 ]
#  [182.8614  ]
#  [163.79764 ]
#  [173.07208 ]
#  [171.66568 ]
#  [165.73306 ]
#  [160.84438 ]
#  [192.08762 ]]
#
# Step : 500
# Cost : 28.949073791503906
# Prediction :
# [[156.25941]
#  [184.18797]
#  [183.44318]
#  [198.51242]
#  [140.64587]
#  [101.35504]
#  [147.75566]
#  [108.46186]
#  [169.76816]
#  [154.14507]
#  [142.58144]
#  [138.51813]
#  [190.74663]
#  [160.14665]
#  [147.75714]
#  [186.03624]
#  [152.93854]
#  [177.33647]
#  [182.60962]
#  [163.56436]
#  [173.17993]
#  [171.79907]
#  [165.78323]
#  [160.41956]
#  [192.04465]]
#
# Step : 600
# Cost : 27.086713790893555
# Prediction :
# [[156.09341]
#  [184.23193]
#  [183.3525 ]
#  [198.51768]
#  [140.6541 ]
#  [101.55007]
#  [147.846  ]
#  [108.6424 ]
#  [169.99287]
#  [154.60493]
#  [142.63422]
#  [138.71751]
#  [190.55063]
#  [159.85129]
#  [147.89578]
#  [186.15755]
#  [152.60646]
#  [177.45416]
#  [182.36873]
#  [163.34135]
#  [173.2838 ]
#  [171.92632]
#  [165.83195]
#  [160.01324]
#  [192.00296]]
#
# Step : 700
# Cost : 25.378890991210938
# Prediction :
# [[155.93518]
#  [184.27335]
#  [183.26575]
#  [198.52295]
#  [140.66095]
#  [101.73604]
#  [147.93323]
#  [108.81668]
#  [170.20709]
#  [155.0445 ]
#  [142.68489]
#  [138.9079 ]
#  [190.36296]
#  [159.56818]
#  [148.02905]
#  [186.27321]
#  [152.28761]
#  [177.56818]
#  [182.13829]
#  [163.1282 ]
#  [173.38385]
#  [172.04768]
#  [165.87929]
#  [159.62462]
#  [191.96251]]
#
# Step : 800
# Cost : 23.812685012817383
# Prediction :
# [[155.78436 ]
#  [184.31232 ]
#  [183.18285 ]
#  [198.5282  ]
#  [140.66655 ]
#  [101.91334 ]
#  [148.01749 ]
#  [108.984924]
#  [170.41136 ]
#  [155.46463 ]
#  [142.73355 ]
#  [139.0897  ]
#  [190.18326 ]
#  [159.29688 ]
#  [148.15715 ]
#  [186.3835  ]
#  [151.9815  ]
#  [177.67863 ]
#  [181.91783 ]
#  [162.92447 ]
#  [173.48027 ]
#  [172.16345 ]
#  [165.9253  ]
#  [159.25294 ]
#  [191.92328 ]]
#
# Step : 900
# Cost : 22.3762264251709
# Prediction :
# [[155.64061]
#  [184.34894]
#  [183.1035 ]
#  [198.53339]
#  [140.67091]
#  [102.08236]
#  [148.09883]
#  [109.14734]
#  [170.6061 ]
#  [155.86618]
#  [142.78027]
#  [139.2633 ]
#  [190.01115]
#  [159.03683]
#  [148.2803 ]
#  [186.48863]
#  [151.68758]
#  [177.78563]
#  [181.70694]
#  [162.72974]
#  [173.57314]
#  [172.27385]
#  [165.96997]
#  [158.89745]
#  [191.88518]]
#
# Step : 1000
# Cost : 21.058618545532227
# Prediction :
# [[155.50365 ]
#  [184.38339 ]
#  [183.02765 ]
#  [198.53857 ]
#  [140.6742  ]
#  [102.2435  ]
#  [148.17743 ]
#  [109.304184]
#  [170.79172 ]
#  [156.24998 ]
#  [142.82516 ]
#  [139.42906 ]
#  [189.84633 ]
#  [158.78758 ]
#  [148.39871 ]
#  [186.58888 ]
#  [151.40533 ]
#  [177.88931 ]
#  [181.5052  ]
#  [162.54361 ]
#  [173.66264 ]
#  [172.37912 ]
#  [166.0134  ]
#  [158.55746 ]
#  [191.84824 ]]
#
# Step : 1100
# Cost : 19.84992027282715
# Prediction :
# [[155.37311 ]
#  [184.41571 ]
#  [182.9551  ]
#  [198.54372 ]
#  [140.67642 ]
#  [102.397095]
#  [148.25336 ]
#  [109.45563 ]
#  [170.96864 ]
#  [156.61682 ]
#  [142.86826 ]
#  [139.58731 ]
#  [189.68848 ]
#  [158.54866 ]
#  [148.51256 ]
#  [186.68445 ]
#  [151.1343  ]
#  [177.98975 ]
#  [181.3122  ]
#  [162.3657  ]
#  [173.7489  ]
#  [172.4795  ]
#  [166.05559 ]
#  [158.2323  ]
#  [191.81238 ]]
#
# Step : 1200
# Cost : 18.741043090820312
# Prediction :
# [[155.24876 ]
#  [184.44604 ]
#  [182.88571 ]
#  [198.54884 ]
#  [140.67767 ]
#  [102.543495]
#  [148.32672 ]
#  [109.60189 ]
#  [171.13728 ]
#  [156.96742 ]
#  [142.90967 ]
#  [139.73842 ]
#  [189.53732 ]
#  [158.31966 ]
#  [148.62204 ]
#  [186.77553 ]
#  [150.87401 ]
#  [178.08708 ]
#  [181.12755 ]
#  [162.19568 ]
#  [173.83202 ]
#  [172.57524 ]
#  [166.0966  ]
#  [157.9213  ]
#  [191.77756 ]]
#
# Step : 1300
# Cost : 17.72362518310547
# Prediction :
# [[155.1303 ]
#  [184.47452]
#  [182.81938]
#  [198.55394]
#  [140.67802]
#  [102.68303]
#  [148.3976 ]
#  [109.74316]
#  [171.298  ]
#  [157.30252]
#  [142.94946]
#  [139.8827 ]
#  [189.39256]
#  [158.10014]
#  [148.72733]
#  [186.86235]
#  [150.62404]
#  [178.18144]
#  [180.95093]
#  [162.0332 ]
#  [173.91216]
#  [172.66653]
#  [166.13646]
#  [157.62386]
#  [191.74377]]
#
# Step : 1400
# Cost : 16.790021896362305
# Prediction :
# [[155.01743 ]
#  [184.50114 ]
#  [182.75592 ]
#  [198.55896 ]
#  [140.67749 ]
#  [102.815994]
#  [148.46606 ]
#  [109.879585]
#  [171.45114 ]
#  [157.62277 ]
#  [142.98767 ]
#  [140.0204  ]
#  [189.25389 ]
#  [157.88968 ]
#  [148.82855 ]
#  [186.94508 ]
#  [150.38391 ]
#  [178.27284 ]
#  [180.78194 ]
#  [161.87788 ]
#  [173.98938 ]
#  [172.75352 ]
#  [166.17519 ]
#  [157.33937 ]
#  [191.71095 ]]
#
# Step : 1500
# Cost : 15.93323040008545
# Prediction :
# [[154.90993]
#  [184.52611]
#  [182.69524]
#  [198.56396]
#  [140.67618]
#  [102.9427 ]
#  [148.53224]
#  [110.0114 ]
#  [171.59708]
#  [157.92885]
#  [143.02437]
#  [140.15189]
#  [189.1211 ]
#  [157.68794]
#  [148.92593]
#  [187.02394]
#  [150.15327]
#  [178.36147]
#  [180.62027]
#  [161.72945]
#  [174.06383]
#  [172.83649]
#  [166.21283]
#  [157.06729]
#  [191.67912]]
#
# Step : 1600
# Cost : 15.146841049194336
# Prediction :
# [[154.80753 ]
#  [184.54945 ]
#  [182.63719 ]
#  [198.56891 ]
#  [140.67412 ]
#  [103.06342 ]
#  [148.5962  ]
#  [110.138725]
#  [171.73611 ]
#  [158.22134 ]
#  [143.05965 ]
#  [140.27739 ]
#  [188.99388 ]
#  [157.49452 ]
#  [149.01959 ]
#  [187.09906 ]
#  [149.93175 ]
#  [178.44737 ]
#  [180.4656  ]
#  [161.58759 ]
#  [174.1356  ]
#  [172.91554 ]
#  [166.24944 ]
#  [156.80705 ]
#  [191.6482  ]]
#
# Step : 1700
# Cost : 14.425026893615723
# Prediction :
# [[154.71002 ]
#  [184.57129 ]
#  [182.58171 ]
#  [198.57379 ]
#  [140.67137 ]
#  [103.178444]
#  [148.65802 ]
#  [110.26176 ]
#  [171.86858 ]
#  [158.5009  ]
#  [143.09354 ]
#  [140.3972  ]
#  [188.87206 ]
#  [157.30908 ]
#  [149.10971 ]
#  [187.17065 ]
#  [149.71892 ]
#  [178.53064 ]
#  [180.31766 ]
#  [161.45203 ]
#  [174.20482 ]
#  [172.9909  ]
#  [166.285   ]
#  [156.5582  ]
#  [191.6182  ]]
#
# Step : 1800
# Cost : 13.762346267700195
# Prediction :
# [[154.61716 ]
#  [184.59164 ]
#  [182.52863 ]
#  [198.57866 ]
#  [140.66798 ]
#  [103.28802 ]
#  [148.71779 ]
#  [110.380646]
#  [171.99475 ]
#  [158.76804 ]
#  [143.1261  ]
#  [140.51155 ]
#  [188.75534 ]
#  [157.13129 ]
#  [149.19638 ]
#  [187.23885 ]
#  [149.51443 ]
#  [178.61139 ]
#  [180.17612 ]
#  [161.32246 ]
#  [174.27158 ]
#  [173.06273 ]
#  [166.31958 ]
#  [156.32016 ]
#  [191.58904 ]]
#
# Step : 1900
# Cost : 13.153936386108398
# Prediction :
# [[154.52875]
#  [184.61063]
#  [182.47789]
#  [198.58345]
#  [140.664  ]
#  [103.39237]
#  [148.77556]
#  [110.49552]
#  [172.11494]
#  [159.02333]
#  [143.1574 ]
#  [140.62071]
#  [188.64357]
#  [156.96082]
#  [149.27977]
#  [187.30382]
#  [149.318  ]
#  [178.68968]
#  [180.04071]
#  [161.19865]
#  [174.33592]
#  [173.13118]
#  [166.3532 ]
#  [156.09251]
#  [191.56075]]
#
# Step : 2000
# Cost : 12.595219612121582
# Prediction :
# [[154.44458 ]
#  [184.62831 ]
#  [182.42934 ]
#  [198.5882  ]
#  [140.65948 ]
#  [103.491776]
#  [148.83142 ]
#  [110.606544]
#  [172.22942 ]
#  [159.26732 ]
#  [143.18747 ]
#  [140.72487 ]
#  [188.53648 ]
#  [156.79736 ]
#  [149.36003 ]
#  [187.36569 ]
#  [149.12923 ]
#  [178.76558 ]
#  [179.91116 ]
#  [161.08032 ]
#  [174.39803 ]
#  [173.19641 ]
#  [166.38588 ]
#  [155.87477 ]
#  [191.53326 ]]

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in tqdm_notebook(range(2001)):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                    feed_dict = {X : x_data, Y : y_data})
    
    if step % 100 == 0 or step < 10:
        print("Step : {} \tCost : {} ".format(step, cost_val))
# Out:
# HBox(children=(IntProgress(value=0, max=2001), HTML(value='')))
# Step : 0 	Cost : 37653.984375
# Step : 1 	Cost : 13947.6103515625
# Step : 2 	Cost : 5182.68701171875
# Step : 3 	Cost : 1942.03369140625
# Step : 4 	Cost : 743.8551635742188
# Step : 5 	Cost : 300.8373107910156
# Step : 6 	Cost : 137.0222625732422
# Step : 7 	Cost : 76.43635559082031
# Step : 8 	Cost : 54.017330169677734
# Step : 9 	Cost : 45.70964050292969
# Step : 100 	Cost : 38.247440338134766
# Step : 200 	Cost : 35.61164855957031
# Step : 300 	Cost : 33.19538497924805
# Step : 400 	Cost : 30.980134963989258
# Step : 500 	Cost : 28.949073791503906
# Step : 600 	Cost : 27.086713790893555
# Step : 700 	Cost : 25.378890991210938
# Step : 800 	Cost : 23.812685012817383
# Step : 900 	Cost : 22.3762264251709
# Step : 1000 	Cost : 21.058618545532227
# Step : 1100 	Cost : 19.84992027282715
# Step : 1200 	Cost : 18.741043090820312
# Step : 1300 	Cost : 17.72362518310547
# Step : 1400 	Cost : 16.790021896362305
# Step : 1500 	Cost : 15.93323040008545
# Step : 1600 	Cost : 15.146841049194336
# Step : 1700 	Cost : 14.425026893615723
# Step : 1800 	Cost : 13.762346267700195
# Step : 1900 	Cost : 13.153936386108398
# Step : 2000 	Cost : 12.595219612121582

# %% [markdown]
# #### predict score

# %%
print("Your score \t: \n", sess.run(hypothesis, feed_dict={X: [[100, 70, 101]]}))
# Out:
# Your score 	:
#  [[180.76924]]

# %%
print("\nOther scores \t: \n", sess.run(hypothesis,
                                        feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# Other scores 	:
#  [[162.21465]
#  [183.13728]]

# %% [markdown]
# #### Tensorflow reader

# %%
import tensorflow as tf

tf.set_random_seed(777)

filename_queue = tf.train.string_input_producer(
                 ['./data/data-01-test-score.csv'], shuffle = False, name = 'filename_queue')
reader = tf.TextLineReader()
key, value = reader.read(filename_queue)

record_defaults = [[0.], [0.], [0.], [0.]]
xy = tf.decode_csv(value, record_defaults=record_defaults)

train_x_batch, train_y_batch = \
    tf.train.batch([xy[0:-1], xy[-1:]], batch_size=10)

print("# Check data")
print("-"*50)
print(train_x_batch)
print("-"*50)
print(train_y_batch)
# Out:
# # Check data
# --------------------------------------------------
# Tensor("batch:0", shape=(10, 3), dtype=float32)
# --------------------------------------------------
# Tensor("batch:1", shape=(10, 1), dtype=float32)

# %%
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = tf.matmul(X, W) + b
cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

coord = tf.train.Coordinator()  # 쓰레드 컨트롤
threads = tf.train.start_queue_runners(sess = sess, coord = coord)

for step in tqdm_notebook(range(2001)):
    x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
    cost_val, hy_val, _ = sess.run(
                          [cost, hypothesis, train], feed_dict = {X : x_batch, Y : y_batch})
    if step % 100 == 0 or step < 10:
        print("\nStep : {} \nCost : {} \nPrediction :\n{}".format(step, cost_val, hy_val))

coord.request_stop()
coord.join(threads)
# Out:
# HBox(children=(IntProgress(value=0, max=2001), HTML(value='')))
# Step : 0
# Cost : 150746.46875
# Prediction :
# [[526.83954]
#  [635.4824 ]
#  [624.72455]
#  [683.38306]
#  [482.76044]
#  [360.8742 ]
#  [515.4113 ]
#  [387.43497]
#  [598.1317 ]
#  [560.9038 ]]
#
# Step : 1
# Cost : 63619.98828125
# Prediction :
# [[365.33612]
#  [362.32755]
#  [473.0038 ]
#  [389.09045]
#  [384.1147 ]
#  [478.5761 ]
#  [367.6042 ]
#  [459.4538 ]
#  [450.13898]
#  [403.08676]]
#
# Step : 2
# Cost : 25774.12890625
# Prediction :
# [[341.24332]
#  [337.61478]
#  [324.30878]
#  [290.4762 ]
#  [368.11182]
#  [295.115  ]
#  [356.89606]
#  [350.26886]
#  [384.46295]
#  [270.2884 ]]
#
# Step : 3
# Cost : 6661.2373046875
# Prediction :
# [[161.94666]
#  [231.2947 ]
#  [176.81024]
#  [267.51257]
#  [254.63928]
#  [220.41837]
#  [219.47598]
#  [282.31863]
#  [230.54694]
#  [233.02338]]
#
# Step : 4
# Cost : 3331.156982421875
# Prediction :
# [[255.10268]
#  [190.06378]
#  [247.15703]
#  [236.36147]
#  [211.8047 ]
#  [239.40222]
#  [236.17914]
#  [227.21346]
#  [199.79512]
#  [256.05914]]
#
# Step : 5
# Cost : 1170.9423828125
# Prediction :
# [[182.83124]
#  [221.94305]
#  [217.29659]
#  [239.64595]
#  [167.36523]
#  [128.31122]
#  [183.25366]
#  [141.1887 ]
#  [211.6119 ]
#  [202.8481 ]]
#
# Step : 6
# Cost : 409.5059509277344
# Prediction :
# [[162.82925]
#  [162.67781]
#  [206.58891]
#  [167.60477]
#  [172.9678 ]
#  [213.04842]
#  [156.66585]
#  [207.20383]
#  [196.1409 ]
#  [175.81645]]
#
# Step : 7
# Cost : 161.20440673828125
# Prediction :
# [[192.09212]
#  [189.06366]
#  [182.1063 ]
#  [157.65878]
#  [204.00822]
#  [163.37611]
#  [198.55128]
#  [194.25291]
#  [214.54678]
#  [149.52544]]
#
# Step : 8
# Cost : 104.8851547241211
# Prediction :
# [[111.88338 ]
#  [159.79233 ]
#  [123.793816]
#  [184.30994 ]
#  [177.55348 ]
#  [151.53215 ]
#  [151.54103 ]
#  [191.72632 ]
#  [155.24864 ]
#  [161.18852 ]]
#
# Step : 9
# Cost : 14.158429145812988
# Prediction :
# [[194.27692]
#  [141.76076]
#  [189.37012]
#  [178.18999]
#  [159.7545 ]
#  [182.93889]
#  [179.94666]
#  [173.3801 ]
#  [149.5136 ]
#  [193.93878]]
#
# Step : 100
# Cost : 14.715252876281738
# Prediction :
# [[152.12305 ]
#  [184.90782 ]
#  [180.87599 ]
#  [199.91487 ]
#  [139.14293 ]
#  [107.386856]
#  [153.45049 ]
#  [119.01004 ]
#  [176.88937 ]
#  [170.52867 ]]
#
# Step : 200
# Cost : 13.988189697265625
# Prediction :
# [[152.20392 ]
#  [184.8847  ]
#  [180.92065 ]
#  [199.89783 ]
#  [139.14954 ]
#  [107.27616 ]
#  [153.37366 ]
#  [118.867134]
#  [176.75952 ]
#  [170.25232 ]]
#
# Step : 300
# Cost : 13.318692207336426
# Prediction :
# [[152.28064]
#  [184.86331]
#  [180.9633 ]
#  [199.88132]
#  [139.15686]
#  [107.17101]
#  [153.29945]
#  [118.72902]
#  [176.63618]
#  [169.98866]]
#
# Step : 400
# Cost : 12.70190715789795
# Prediction :
# [[152.35342]
#  [184.84355]
#  [181.00407]
#  [199.86539]
#  [139.16489]
#  [107.07117]
#  [153.22775]
#  [118.59552]
#  [176.51904]
#  [169.73709]]
#
# Step : 500
# Cost : 12.133415222167969
# Prediction :
# [[152.42242]
#  [184.82536]
#  [181.04303]
#  [199.84998]
#  [139.17352]
#  [106.97634]
#  [153.15848]
#  [118.46645]
#  [176.40784]
#  [169.4971 ]]
#
# Step : 600
# Cost : 11.609195709228516
# Prediction :
# [[152.48785 ]
#  [184.80862 ]
#  [181.08026 ]
#  [199.83508 ]
#  [139.18275 ]
#  [106.88632 ]
#  [153.09154 ]
#  [118.341675]
#  [176.30226 ]
#  [169.26816 ]]
#
# Step : 700
# Cost : 11.12553596496582
# Prediction :
# [[152.54987]
#  [184.79327]
#  [181.11584]
#  [199.8207 ]
#  [139.19249]
#  [106.80088]
#  [153.02684]
#  [118.22102]
#  [176.20206]
#  [169.04973]]
#
# Step : 800
# Cost : 10.679058074951172
# Prediction :
# [[152.60863]
#  [184.77922]
#  [181.14986]
#  [199.8068 ]
#  [139.20271]
#  [106.71977]
#  [152.96431]
#  [118.10435]
#  [176.10696]
#  [168.84137]]
#
# Step : 900
# Cost : 10.266680717468262
# Prediction :
# [[152.6643 ]
#  [184.7664 ]
#  [181.18236]
#  [199.79333]
#  [139.21338]
#  [106.64282]
#  [152.90387]
#  [117.9915 ]
#  [176.01675]
#  [168.64261]]
#
# Step : 1000
# Cost : 9.885621070861816
# Prediction :
# [[152.71706 ]
#  [184.75476 ]
#  [181.21342 ]
#  [199.78033 ]
#  [139.22443 ]
#  [106.56981 ]
#  [152.84544 ]
#  [117.882355]
#  [175.93117 ]
#  [168.45303 ]]
#
# Step : 1100
# Cost : 9.533247947692871
# Prediction :
# [[152.76701 ]
#  [184.7442  ]
#  [181.2431  ]
#  [199.76776 ]
#  [139.23584 ]
#  [106.500565]
#  [152.78896 ]
#  [117.77678 ]
#  [175.84999 ]
#  [168.27217 ]]
#
# Step : 1200
# Cost : 9.207234382629395
# Prediction :
# [[152.8143 ]
#  [184.7347 ]
#  [181.27148]
#  [199.7556 ]
#  [139.24756]
#  [106.43488]
#  [152.73433]
#  [117.67464]
#  [175.77304]
#  [168.09967]]
#
# Step : 1300
# Cost : 8.90544605255127
# Prediction :
# [[152.85904]
#  [184.72612]
#  [181.29858]
#  [199.74384]
#  [139.25955]
#  [106.37262]
#  [152.6815 ]
#  [117.57582]
#  [175.70004]
#  [167.93515]]
#
# Step : 1400
# Cost : 8.62588119506836
# Prediction :
# [[152.9014 ]
#  [184.71849]
#  [181.32451]
#  [199.73245]
#  [139.2718 ]
#  [106.31358]
#  [152.63042]
#  [117.48019]
#  [175.6309 ]
#  [167.77823]]
#
# Step : 1500
# Cost : 8.366792678833008
# Prediction :
# [[152.94145 ]
#  [184.71173 ]
#  [181.34927 ]
#  [199.72145 ]
#  [139.28427 ]
#  [106.257645]
#  [152.58102 ]
#  [117.38765 ]
#  [175.56535 ]
#  [167.62857 ]]
#
# Step : 1600
# Cost : 8.126447677612305
# Prediction :
# [[152.97932 ]
#  [184.70576 ]
#  [181.37294 ]
#  [199.7108  ]
#  [139.29694 ]
#  [106.204636]
#  [152.5332  ]
#  [117.29808 ]
#  [175.50325 ]
#  [167.48584 ]]
#
# Step : 1700
# Cost : 7.90344762802124
# Prediction :
# [[153.01514 ]
#  [184.70056 ]
#  [181.39558 ]
#  [199.7005  ]
#  [139.30977 ]
#  [106.15442 ]
#  [152.48698 ]
#  [117.211395]
#  [175.44446 ]
#  [167.34973 ]]
#
# Step : 1800
# Cost : 7.696341037750244
# Prediction :
# [[153.04898 ]
#  [184.69608 ]
#  [181.4172  ]
#  [199.69054 ]
#  [139.32274 ]
#  [106.106865]
#  [152.44225 ]
#  [117.12747 ]
#  [175.38878 ]
#  [167.21994 ]]
#
# Step : 1900
# Cost : 7.503898620605469
# Prediction :
# [[153.08095 ]
#  [184.69228 ]
#  [181.43788 ]
#  [199.6809  ]
#  [139.3358  ]
#  [106.06184 ]
#  [152.39896 ]
#  [117.046234]
#  [175.33606 ]
#  [167.09618 ]]
#
# Step : 2000
# Cost : 7.324863433837891
# Prediction :
# [[153.11113]
#  [184.68907]
#  [181.45761]
#  [199.67152]
#  [139.34897]
#  [106.01921]
#  [152.35704]
#  [116.96756]
#  [175.28616]
#  [166.97813]]

# %% [markdown]
# #### predcit score

# %%
print("Your score \t: \n", sess.run(hypothesis, feed_dict={X: [[100, 70, 101]]}))

print("\nOther scores \t: \n", sess.run(hypothesis,
                                        feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# Your score 	:
#  [[187.20932]]
#
# Other scores 	:
#  [[194.0139 ]
#  [171.56538]]
