# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s.dtype
# Out:
# dtype('float64')

# %%
date = pd.DataFrame({'A': 1.,
                     'B': pd.Timestamp('20130102'),
                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                     'D': np.array([3]*4, dtype='int32'),
                     'E': pd.Categorical(['test', 'train', 'test', 'train']),
                     'F': 'foo'})

# %%
date
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
date.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
date.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
dir(date)
# Out:
# ['A',
#  'B',
#  'C',
#  'D',
#  'E',
#  'F',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
date.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
date.tail()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
date.tail(2)
# Out:
#      A          B    C  D      E    F
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
date.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
date.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
date.values
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
dates = pd.date_range('20180910', periods = 6)
dates
# Out:
# DatetimeIndex(['2018-09-10', '2018-09-11', '2018-09-12', '2018-09-13',
#                '2018-09-14', '2018-09-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2018-09-10  0.398911  0.265409  0.193372  0.468530
# 2018-09-11  0.435566 -0.833198 -1.386155 -0.513973
# 2018-09-12 -1.941780  0.043025  0.333917 -0.121322
# 2018-09-13  1.581320  1.269480 -0.571177 -1.020457
# 2018-09-14 -1.040970  0.961136  0.609584  1.556438
# 2018-09-15  0.500879  0.542033 -0.031645  0.334207

# %%
df.head()
# Out:
#                    A         B         C         D
# 2018-09-10  0.398911  0.265409  0.193372  0.468530
# 2018-09-11  0.435566 -0.833198 -1.386155 -0.513973
# 2018-09-12 -1.941780  0.043025  0.333917 -0.121322
# 2018-09-13  1.581320  1.269480 -0.571177 -1.020457
# 2018-09-14 -1.040970  0.961136  0.609584  1.556438

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2018-09-13  1.581320  1.269480 -0.571177 -1.020457
# 2018-09-14 -1.040970  0.961136  0.609584  1.556438
# 2018-09-15  0.500879  0.542033 -0.031645  0.334207

# %%
df.index
# Out:
# DatetimeIndex(['2018-09-10', '2018-09-11', '2018-09-12', '2018-09-13',
#                '2018-09-14', '2018-09-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.39891076,  0.26540868,  0.19337194,  0.4685302 ],
#        [ 0.43556618, -0.83319787, -1.38615501, -0.51397308],
#        [-1.94178025,  0.04302457,  0.33391746, -0.12132247],
#        [ 1.58131988,  1.26947961, -0.57117676, -1.0204575 ],
#        [-1.04097042,  0.96113612,  0.60958425,  1.55643841],
#        [ 0.50087864,  0.54203331, -0.03164471,  0.33420688]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.011013  0.374647 -0.142017  0.117237
# std    1.261246  0.742093  0.727756  0.893473
# min   -1.941780 -0.833198 -1.386155 -1.020457
# 25%   -0.681000  0.098621 -0.436294 -0.415810
# 50%    0.417238  0.403721  0.080864  0.106442
# 75%    0.484551  0.856360  0.298781  0.434949
# max    1.581320  1.269480  0.609584  1.556438

# %%
df.head()
# Out:
#                    A         B         C         D
# 2018-09-10  0.398911  0.265409  0.193372  0.468530
# 2018-09-11  0.435566 -0.833198 -1.386155 -0.513973
# 2018-09-12 -1.941780  0.043025  0.333917 -0.121322
# 2018-09-13  1.581320  1.269480 -0.571177 -1.020457
# 2018-09-14 -1.040970  0.961136  0.609584  1.556438

# %%
df.T
# Out:
#    2018-09-10  2018-09-11  2018-09-12  2018-09-13  2018-09-14  2018-09-15
# A    0.398911    0.435566   -1.941780    1.581320   -1.040970    0.500879
# B    0.265409   -0.833198    0.043025    1.269480    0.961136    0.542033
# C    0.193372   -1.386155    0.333917   -0.571177    0.609584   -0.031645
# D    0.468530   -0.513973   -0.121322   -1.020457    1.556438    0.334207

# %%
df.T()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-e5fa925afb57> in <module>()
# ----> 1 df.T()
#
# TypeError: 'DataFrame' object is not callable

# %%
df.sort_index(axis = 1, ascending = False) 

# ascending = True 오름차순
# ascending = Flas 내림차순
# Out:
#                    D         C         B         A
# 2018-09-10  0.468530  0.193372  0.265409  0.398911
# 2018-09-11 -0.513973 -1.386155 -0.833198  0.435566
# 2018-09-12 -0.121322  0.333917  0.043025 -1.941780
# 2018-09-13 -1.020457 -0.571177  1.269480  1.581320
# 2018-09-14  1.556438  0.609584  0.961136 -1.040970
# 2018-09-15  0.334207 -0.031645  0.542033  0.500879

# %%
df.sort_values(by = 'B')
# Out:
#                    A         B         C         D
# 2018-09-11  0.435566 -0.833198 -1.386155 -0.513973
# 2018-09-12 -1.941780  0.043025  0.333917 -0.121322
# 2018-09-10  0.398911  0.265409  0.193372  0.468530
# 2018-09-15  0.500879  0.542033 -0.031645  0.334207
# 2018-09-14 -1.040970  0.961136  0.609584  1.556438
# 2018-09-13  1.581320  1.269480 -0.571177 -1.020457

# %%
df.sort_values(by = 'C')
# Out:
#                    A         B         C         D
# 2018-09-11  0.435566 -0.833198 -1.386155 -0.513973
# 2018-09-13  1.581320  1.269480 -0.571177 -1.020457
# 2018-09-15  0.500879  0.542033 -0.031645  0.334207
# 2018-09-10  0.398911  0.265409  0.193372  0.468530
# 2018-09-12 -1.941780  0.043025  0.333917 -0.121322
# 2018-09-14 -1.040970  0.961136  0.609584  1.556438

# %%
df['A']
# Out:
# 2018-09-10    0.398911
# 2018-09-11    0.435566
# 2018-09-12   -1.941780
# 2018-09-13    1.581320
# 2018-09-14   -1.040970
# 2018-09-15    0.500879
# Freq: D, Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2018-09-10  0.398911  0.265409  0.193372  0.468530
# 2018-09-11  0.435566 -0.833198 -1.386155 -0.513973
# 2018-09-12 -1.941780  0.043025  0.333917 -0.121322

# %%
df[1:3]
# Out:
#                    A         B         C         D
# 2018-09-11  0.435566 -0.833198 -1.386155 -0.513973
# 2018-09-12 -1.941780  0.043025  0.333917 -0.121322

# %%
df['20180912':'20180914']
# Out:
#                   A         B         C         D
# 2018-09-12 -1.94178  0.043025  0.333917 -0.121322
# 2018-09-13  1.58132  1.269480 -0.571177 -1.020457
# 2018-09-14 -1.04097  0.961136  0.609584  1.556438

# %%
df[:-1]
# Out:
#                    A         B         C         D
# 2018-09-10  0.398911  0.265409  0.193372  0.468530
# 2018-09-11  0.435566 -0.833198 -1.386155 -0.513973
# 2018-09-12 -1.941780  0.043025  0.333917 -0.121322
# 2018-09-13  1.581320  1.269480 -0.571177 -1.020457
# 2018-09-14 -1.040970  0.961136  0.609584  1.556438

# %%
df[:-2]
# Out:
#                    A         B         C         D
# 2018-09-10  0.398911  0.265409  0.193372  0.468530
# 2018-09-11  0.435566 -0.833198 -1.386155 -0.513973
# 2018-09-12 -1.941780  0.043025  0.333917 -0.121322
# 2018-09-13  1.581320  1.269480 -0.571177 -1.020457

# %%
df.loc[dates[0]]
# Out:
# A    0.398911
# B    0.265409
# C    0.193372
# D    0.468530
# Name: 2018-09-10 00:00:00, dtype: float64

# %%
df.loc['20180911']
# Out:
# A    0.435566
# B   -0.833198
# C   -1.386155
# D   -0.513973
# Name: 2018-09-11 00:00:00, dtype: float64

# %%
df.loc['2018-09-11']
# Out:
# A    0.435566
# B   -0.833198
# C   -1.386155
# D   -0.513973
# Name: 2018-09-11 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2018-09-10  0.398911  0.265409
# 2018-09-11  0.435566 -0.833198
# 2018-09-12 -1.941780  0.043025
# 2018-09-13  1.581320  1.269480
# 2018-09-14 -1.040970  0.961136
# 2018-09-15  0.500879  0.542033

# %%
df.loc['20180911':'20180913', ['A', 'B']]
# Out:
#                    A         B
# 2018-09-11  0.435566 -0.833198
# 2018-09-12 -1.941780  0.043025
# 2018-09-13  1.581320  1.269480

# %%
df.loc[dates[0], ['A', 'B']]
# Out:
# A    0.398911
# B    0.265409
# Name: 2018-09-10 00:00:00, dtype: float64

# %%
df.loc[dates[0], 'A']
# Out:
# 0.39891075998818837

# %%
df.at[dates[0], 'A']
# Out:
# 0.39891075998818837

# %%
df.mean()   # 컬럼별 평균
# Out:
# A   -0.011013
# B    0.374647
# C   -0.142017
# D    0.117237
# dtype: float64

# %%
df.mean(1)  # 인덱스별 평균
# Out:
# 2018-09-10    0.331555
# 2018-09-11   -0.574440
# 2018-09-12   -0.421540
# 2018-09-13    0.314791
# 2018-09-14    0.521547
# 2018-09-15    0.336369
# Freq: D, dtype: float64

# %%
df1 = pd.DataFrame({'이름' : ['Kane', 'Jane', 'Karl', 'Mike', 'Alice', 'Jack', 'Sara'],
                    '날짜' : [201601, 201602, 201603, 201602,  201604,  201601, 201605],
                    '숙소' : ['Seoul', 'Busan', 'Deajun', 'Seoul', 'Incheon', 'Incheon', 'Seoul']
                     }, columns = ['이름', '날짜', '숙소']);df1
# Out:
#       이름      날짜       숙소
# 0   Kane  201601    Seoul
# 1   Jane  201602    Busan
# 2   Karl  201603   Deajun
# 3   Mike  201602    Seoul
# 4  Alice  201604  Incheon
# 5   Jack  201601  Incheon
# 6   Sara  201605    Seoul

# %%
df1.head(3)
# Out:
#      이름      날짜      숙소
# 0  Kane  201601   Seoul
# 1  Jane  201602   Busan
# 2  Karl  201603  Deajun

# %%
df1.groupby('숙소')

# %%
df1.T
# Out:
#          0       1       2       3        4        5       6
# 이름    Kane    Jane    Karl    Mike    Alice     Jack    Sara
# 날짜  201601  201602  201603  201602   201604   201601  201605
# 숙소   Seoul   Busan  Deajun   Seoul  Incheon  Incheon   Seoul

# %%
df1.pivot('이름', '숙소')
# Out:
#              날짜
# 숙소        Busan    Deajun   Incheon     Seoul
# 이름
# Alice       NaN       NaN  201604.0       NaN
# Jack        NaN       NaN  201601.0       NaN
# Jane   201602.0       NaN       NaN       NaN
# Kane        NaN       NaN       NaN  201601.0
# Karl        NaN  201603.0       NaN       NaN
# Mike        NaN       NaN       NaN  201602.0
# Sara        NaN       NaN       NaN  201605.0

# %%
df1.groupby(df1.숙소).sum()
# Out:
#              날짜
# 숙소
# Busan    201602
# Deajun   201603
# Incheon  403205
# Seoul    604808

# %%
df1.groupby(df1.이름).sum()
# Out:
#            날짜
# 이름
# Alice  201604
# Jack   201601
# Jane   201602
# Kane   201601
# Karl   201603
# Mike   201602
# Sara   201605

# %%
pizza_sales = pd.DataFrame({'date' : [201801, 201802, 201803, 201804,  201805,  201806, 
                                      201807, 201808, 201809, 201810,  201800,  201812],
                            
                            'mean_of slaes' : [481, 567, 321, 350, 333, 456, 
                                               478, 492, 523, 582, 450, 411],       
                            
                            'best slaes'    : [503, 621, 348, 376, 394, 493, 
                                               547, 532, 555, 631, 560, 460],
                            
                            'worst slaes'   : [345, 401, 287, 315, 302, 421, 
                                               399, 423, 501, 385, 420, 377],
                            
                            'best branch'  : ['Seoul', 'Busan', 'Seoul', 'Deajun' ,  'Guri',  'Seoul', 
                                             'Chuncheon', 'Guri','Gwangju','Incheon',  'Busan',  'Seoul'],
                            
                            'worts branch' : ['Chuncheon','Chuncheon',  'Deajun', 'Guri',  'Busan', 'Gwangju', 
                                              'Seoul', 'Chuncheon', 'Deajun', 'Busan',  'Seoul',  'Incheon'],
                            
                            'best pizza'   : ['cheese', 'potato', 'combination', 'peperony',  'hawaiian',  'chicken', 
                                            'seefood', 'steak', 'sweet potato', 'steak', 'cheese',  'seefood'],
                           
                            'worst pizza'   : ['chicken' , 'cheese', 'combination', 'combination',  'peperony', 'hawaiian', 
                                             'steak', 'seefood', 'cheese', 'peperony',  'peperony', 'sweet potato'],
                            
                            'Quater'        : ['1Q', '1Q', '1Q', '2Q', '2Q', '2Q', '3Q', '3Q', '3Q', '4Q', '4Q', '4Q']
                           
                             });pizza_sales
# Out:
#       date  mean_of slaes  best slaes  worst slaes best branch worts branch  \
# 0   201801            481         503          345       Seoul    Chuncheon
# 1   201802            567         621          401       Busan    Chuncheon
# 2   201803            321         348          287       Seoul       Deajun
# 3   201804            350         376          315      Deajun         Guri
# 4   201805            333         394          302        Guri        Busan
# 5   201806            456         493          421       Seoul      Gwangju
# 6   201807            478         547          399   Chuncheon        Seoul
# 7   201808            492         532          423        Guri    Chuncheon
# 8   201809            523         555          501     Gwangju       Deajun
# 9   201810            582         631          385     Incheon        Busan
# 10  201800            450         560          420       Busan        Seoul
# ...

# %%
groupby

    size(), count(): 갯수
    mean(), median(), min(), max(): 평균, 중앙값, 최소, 최대
    sum(), prod(), std(), var(), quantile() : 합계, 곱, 표준편차, 분산, 사분위수
    first(), last(): 가장 첫번째 데이터와 가장 나중 데이터


    agg(), aggregate()
        만약 원하는 그룹 연산이 없는 경우 함수를 만들고 이 함수를 agg()에 전달한다.
        또는 여러가지 그룹 연산을 동시에 하고 싶은 경우 함수 이름 문자열의 리스트를 전달한다.

    describe()
        하나의 그룹 대표값이 아니라 여러개의 값을 데이터프레임으로 구한다.

    apply()
        describe() 처럼 하나의 대표값이 아닌 데이터프레임을 출력하지만 원하는 그룹 연산이 없는 경우에 사용한다.

    transform()
        그룹에 대한 대표값을 만드는 것이 아니라 그룹별 계산을 통해 데이터 자체를 변형한다.

# %%
weather = weather.fillna(method = 'ffill', limit=1) # 앞 방향으로 결측값(NaN)채우기 & 횟수를 1회로 제한
weather = weather.fillna(method = 'bfill', limit=1) # 뒷 방향으로 결측값(NaN)채우기 & 횟수를 1회로 제한
weather = weather.fillna(weather.mean()) # 결측값(NaN)을 변수별 평균으로 대체하기

# %%
pd.crosstab(index=weather['pickup_hour'],columns = 'count')

# %%
https://datascienceschool.net/view-notebook/7002e92653434bc88c8c026c3449d27b/
https://datascienceschool.net/view-notebook/76dcd63bba2c4959af15bec41b197e7c/

# %%
df1 = pd.DataFrame({'이름' : ['Kane', 'Jane', 'Karl', 'Mike', 'Alice', 'Jack', 'Sara'],
                    '날짜' : [201601, 201602, 201603, 201602,  201604,  201601, 201605],
                    '숙소' : ['Seoul', 'Busan', 'Deajun', 'Seoul', 'Incheon', 'Incheon', 'Seoul']
                     }, columns = ['이름', '날짜', '숙소']);df1

# %%
df2 = pd.DataFrame({'날짜' : [201601, 201602, 201603, 201604,  201605,  201606, 201607],
                    '수업' : ['수학', '국어', '사회', '과학', '영어', '한자', '음악']
                    }, columns = ['날짜', '수업']);df2

# %%
pd.merge(df1, df2)

# %%
df3 = pd.DataFrame({'날짜' : [201601, 201602, 201603, 201604,  201605],
                    '수업' : ['수학', '국어', '사회', '과학', '영어']
                    }, columns = ['날짜', '수업']);df3

# %%
pd.merge(df1, df3)
